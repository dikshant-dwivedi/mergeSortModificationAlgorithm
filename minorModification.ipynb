# %%
'''required libraries'''
import time
import random

# %%
'''Insertion sort'''
def insertionSort(arr):
    for i in range(1, len(arr)):
        key = arr[i]
        j = i-1
        while j >= 0 and key < arr[j] :
            arr[j + 1] = arr[j]
            j -= 1
        arr[j + 1] = key

# %%
'''Selection sort'''
def selectionSort(A):
    for i in range(len(A)):
        min_idx = i
        for j in range(i+1, len(A)):
            if A[min_idx] > A[j]:
                min_idx = j    
        A[i], A[min_idx] = A[min_idx], A[i]

# %%
'''Min max selection sort'''
def minMaxSelectionSort(arr, n):
    i = 0
    j = n - 1
    while(i < j):
        min = arr[i]
        max = arr[i]
        min_i = i
        max_i = i
        for k in range(i, j + 1, 1):
            if (arr[k] > max):
                max = arr[k]
                max_i = k
            elif (arr[k] < min):
                min = arr[k]
                min_i = k
          
        temp = arr[i]
        arr[i] = arr[min_i]
        arr[min_i] = temp

        if (arr[min_i] == max):
            temp = arr[j]
            arr[j] = arr[min_i]
            arr[min_i] = temp
        else:
            temp = arr[j]
            arr[j] = arr[max_i]
            arr[max_i] = temp
  
        i += 1
        j -= 1

# %%
'''Two way merge function'''
def merge(L, R, arr):
    i = j = k = 0
    while i < len(L) and j < len(R):
        if L[i] < R[j]:
            arr[k] = L[i]
            i += 1
        else:
            arr[k] = R[j]
            j += 1
        k += 1

    while i < len(L):
        arr[k] = L[i]
        i += 1
        k += 1

    while j < len(R):
        arr[k] = R[j]
        j += 1
        k += 1

# %%
'''function to print array'''
def printList(arr):
	  for i in range(len(arr)):
		    print(arr[i], end=" ")
	  print()

# %%
if __name__ == '__main__':

    arr = []
    random.seed(10)
    for i in range(0, 1000):
        n = random.randint(0,1000)
        arr.append(n)
    print("Given array is", end="\n")
    printList(arr)
    start_time = time.time()
    minMaxSelectionSort(arr, len(arr))
    print("Sorted array is (Min max): ", end="\n")
    printList(arr)
    print(time.time()-start_time)

    arr = []
    random.seed(10)
    for i in range(0, 1000):
        n = random.randint(0,1000)
        arr.append(n)
    start_time = time.time()
    insertionSort(arr)
    print("Sorted array is (Insertion): ", end="\n")
    printList(arr)
    print(time.time()-start_time)

    arr = []
    random.seed(10)
    for i in range(0, 1000):
        n = random.randint(0,1000)
        arr.append(n)
    start_time = time.time()
    selectionSort(arr)
    print("Sorted array is (Selection): ", end="\n")
    printList(arr)
    print(time.time()-start_time)
# Out:
# Given array is
# ...

# %%
'''Untweaked merge sort function''' 
import time
import random
def mergeSort(arr):
	if len(arr) > 1:
		mid = len(arr)//2

		L = arr[:mid]
		R = arr[mid:]

		mergeSort(L)
		mergeSort(R)

		i = j = k = 0

		while i < len(L) and j < len(R):
			if L[i] < R[j]:
				arr[k] = L[i]
				i += 1
			else:
				arr[k] = R[j]
				j += 1
			k += 1

		while i < len(L):
			arr[k] = L[i]
			i += 1
			k += 1

		while j < len(R):
			arr[k] = R[j]
			j += 1
			k += 1

if __name__ == '__main__':
    arr = []
    random.seed(10)
    for i in range(0, 1000):
        n = random.randint(0,1000)
        arr.append(n)
    print("Given array is", end="\n")
    printList(arr)
    start_time = time.time()
    mergeSort(arr)
    print("Sorted array is: ", end="\n")
    printList(arr)
    end_time = time.time()
    print(end_time-start_time)
# Out:
# Given array is
# ...

# %%
'''Merge function with 2 halves running either insertion or min-max sort'''
def mergeSort(arr, size):

    if len(arr) > size:
        mid = len(arr)//2

        L = arr[:mid]
        R = arr[mid:]

        mergeSort(L, size)
        mergeSort(R, size)
      
        merge(L, R, arr)
    
    else:
        insertionSort(arr)
      #minMaxSelectionSort(arr, len(arr))

if __name__ == '__main__':

    arr = []
    random.seed(10)
    for i in range(0, 1000):
        n = random.randint(0,1000)
        arr.append(n)

    print("Given array is", end="\n")
    printList(arr)

    start_time = time.time()
    mergeSort(arr, 1000)
    print("Sorted array is: ", end="\n")
    printList(arr)
    print(time.time()-start_time)
# Out:
# Given array is
# ...

# %%
'''Merge function with 3 halves running either insertion or min-max sort'''
def mergeSort(arr, size):

    if len(arr) > size:
        mid = len(arr)//3

        L = arr[:mid]
        M = arr[mid: 2*mid]
        R = arr[2*mid:]

        mergeSort(L, size)
        mergeSort(M, size)
        mergeSort(R, size)
      
        temp = arr[0: 2*mid]
        merge(L, M, temp)
        merge(temp, R, arr)
    
    else:
        #insertionSort(arr)
        minMaxSelectionSort(arr, len(arr))


if __name__ == '__main__':

    arr = []
    random.seed(10)
    for i in range(0, 1000):
        n = random.randint(0,1000)
        arr.append(n)

    print("Given array is", end="\n")
    printList(arr)

    start_time = time.time()
    mergeSort(arr, 1000)
    print("Sorted array is: ", end="\n")
    printList(arr)
    print(time.time()-start_time)
# Out:
# Given array is
# ...

# %%
'''Merge function with 4 halves running either insertion or min-max sort'''
def mergeSort(arr, size):

    if len(arr) > size:
        mid = len(arr)//4

        L = arr[:mid]
        M1 = arr[mid: 2*mid]
        M2 = arr[2*mid: 3*mid]
        R = arr[3*mid: ]

        mergeSort(L, size)
        mergeSort(M1, size)
        mergeSort(M2, size)
        mergeSort(R, size)
      
        temp1 = arr[0: 2*mid]
        temp2 = arr[0 : 3*mid]
        merge(L, M1, temp1)
        merge(temp1, M2, temp2)
        merge(temp2, R, arr)
    
    else:
        #insertionSort(arr)
        minMaxSelectionSort(arr, len(arr))

if __name__ == '__main__':

    arr = []
    random.seed(10)
    for i in range(0, 1000):
        n = random.randint(0,1000)
        arr.append(n)

    print("Given array is", end="\n")
    printList(arr)

    start_time = time.time()
    mergeSort(arr, 1000)
    print("Sorted array is: ", end="\n")
    printList(arr)
    print(time.time()-start_time)
# Out:
# Given array is
# ...

# %%
'''Merge function with 4 halves running either insertion or min-max sort'''
def mergeSort(arr, size):

    if len(arr) > size:
        mid = len(arr)//4

        L = arr[:mid]
        M1 = arr[mid: 2*mid]
        M2 = arr[2*mid: 3*mid]
        R = arr[3*mid: ]

        mergeSort(L, size)
        mergeSort(M1, size)
        mergeSort(M2, size)
        mergeSort(R, size)
      
        temp1 = arr[0: 2*mid]
        temp2 = arr[0 : 3*mid]
        merge(L, M1, temp1)
        merge(temp1, M2, temp2)
        merge(temp2, R, arr)
    
    else:
        #insertionSort(arr)
        minMaxSelectionSort(arr, len(arr))

if __name__ == '__main__':

    arr = []
    random.seed(10)
    for i in range(0, 1000):
        n = random.randint(0,1000)
        arr.append(n)

    print("Given array is", end="\n")
    printList(arr)

    start_time = time.time()
    mergeSort(arr, 1000)
    print("Sorted array is: ", end="\n")
    printList(arr)
    print(time.time()-start_time)
# Out:
# Given array is
# ...

# %%
'''Merge function with 5 halves running either insertion or min-max sort'''
def mergeSort(arr, size):

    if len(arr) > size:
        mid = len(arr)//5

        L = arr[:mid]
        M1 = arr[mid: 2*mid]
        M2 = arr[2*mid: 3*mid]
        M3 = arr[3*mid: 4*mid]
        R = arr[4*mid: ]

        mergeSort(L, size)
        mergeSort(M1, size)
        mergeSort(M2, size)
        mergeSort(M3, size)
        mergeSort(R, size)
      
        temp1 = arr[0: 2*mid]
        temp2 = arr[0 : 3*mid]
        temp3 = arr[0: 4*mid]
        merge(L, M1, temp1)
        merge(temp1, M2, temp2)
        merge(temp2, M3, temp3)
        merge(temp3, R, arr)
    
    else:
        #insertionSort(arr)
        minMaxSelectionSort(arr, len(arr))

if __name__ == '__main__':

    arr = []
    random.seed(10)
    for i in range(0, 1000):
        n = random.randint(0,1000)
        arr.append(n)

    print("Given array is", end="\n")
    printList(arr)

    start_time = time.time()
    mergeSort(arr, 1000)
    print("Sorted array is: ", end="\n")
    printList(arr)
    print(time.time()-start_time)
# Out:
# Given array is
# ...

# %%
'''Merge function with 6 halves running either insertion or min-max sort'''
def mergeSort(arr, size):

    if len(arr) > size:
        mid = len(arr)//6

        L = arr[:mid]
        M1 = arr[mid: 2*mid]
        M2 = arr[2*mid: 3*mid]
        M3 = arr[3*mid: 4*mid]
        M4 = arr[4*mid: 5*mid]
        R = arr[5*mid: ]

        mergeSort(L, size)
        mergeSort(M1, size)
        mergeSort(M2, size)
        mergeSort(M3, size)
        mergeSort(M4, size)
        mergeSort(R, size)
      
        temp1 = arr[0: 2*mid]
        temp2 = arr[0 : 3*mid]
        temp3 = arr[0: 4*mid]
        temp4 = arr[0: 5*mid]
        merge(L, M1, temp1)
        merge(temp1, M2, temp2)
        merge(temp2, M3, temp3)
        merge(temp3, M4, temp4)
        merge(temp4, R, arr)
    
    else:
        #insertionSort(arr)
        minMaxSelectionSort(arr, len(arr))

if __name__ == '__main__':
    arr = []
    random.seed(10)
    for i in range(0, 1000):
        n = random.randint(0,1000)
        arr.append(n)

    print("Given array is", end="\n")
    printList(arr)

    start_time = time.time()
    mergeSort(arr, 1000)
    print("Sorted array is: ", end="\n")
    printList(arr)
    print(time.time()-start_time)
# Out:
# Given array is
# ...
